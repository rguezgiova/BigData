# %%
# %scala
import org.apache.spark.sql.SparkSession

val session = SparkSession.builder.appName("Quijote").getOrCreate()

val file = "/FileStore/shared_uploads/giovanni.rodriguez@bosonit.com/el_quijote.txt"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import org.apache.spark.sql.SparkSession
# session: org.apache.spark.sql.SparkSession = org.apache.spark.sql.SparkSession@3500ecd3
# file: String = /FileStore/shared_uploads/giovanni.rodriguez@bosonit.com/el_quijote.txt
# </div>

# %%
# %scala
val dataFrame = session.read.text(file)
dataFrame.persist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dataFrame: org.apache.spark.sql.DataFrame = [value: string]
# res0: dataFrame.type = [value: string]
# </div>

# %%
# %scala
dataFrame.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Long = 2186
# </div>

# %%
# %scala
dataFrame.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#                value|
# +--------------------+
# DON QUIJOTE DE LA...|
# Miguel de Cervant...|
#                     |
#        PRIMERA PARTE|
# CAPÍTULO 1: Que ...|
# En un lugar de la...|
# Tuvo muchas veces...|
# En resolución, e...|
# historia más cie...|
# Decía él, que e...|
# En efecto, remata...|
# Imaginábase el p...|
# linaje y patria, ...|
# Limpias, pues, su...|
# Capítulo 2: Que ...|
# Hechas, pues, est...|
# Estos pensamiento...|
# Con estos iba ens...|
# Autores hay que d...|
# muertos de hambre...|
# +--------------------+
# only showing top 20 rows
#
# </div>

# %%
# %scala
dataFrame.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#                value|
# +--------------------+
# DON QUIJOTE DE LA...|
# Miguel de Cervant...|
#                     |
#        PRIMERA PARTE|
# CAPÍTULO 1: Que ...|
# +--------------------+
# only showing top 5 rows
#
# </div>

# %%
# %scala
dataFrame.show(5, truncate=false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------------------------------------------------------------------------------------+
# value                                                                                         |
# +----------------------------------------------------------------------------------------------+
# DON QUIJOTE DE LA MANCHA                                                                      |
# Miguel de Cervantes Saavedra                                                                  |
#                                                                                               |
# ...

# %%
# %scala
dataFrame.show(false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
# %scala
dataFrame.first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res7: org.apache.spark.sql.Row = [DON QUIJOTE DE LA MANCHA]
# </div>

# %%
# %scala
dataFrame.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res8: org.apache.spark.sql.Row = [DON QUIJOTE DE LA MANCHA]
# </div>

# %%
# %scala
dataFrame.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res9: Array[org.apache.spark.sql.Row] = Array([DON QUIJOTE DE LA MANCHA], [Miguel de Cervantes Saavedra], [], [PRIMERA PARTE], [CAPÍTULO 1: Que trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha])
# </div>

# %%
# %scala
dataFrame.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res10: Array[org.apache.spark.sql.Row] = Array([DON QUIJOTE DE LA MANCHA], [Miguel de Cervantes Saavedra], [], [PRIMERA PARTE], [CAPÍTULO 1: Que trata de la condición y ejercicio del famoso hidalgo D. Quijote de la Mancha])
# </div>

# %%
# %scala
  session.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
