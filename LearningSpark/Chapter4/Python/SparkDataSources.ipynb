# %% [markdown]
# ## Spark Data Sources
#
# Este notebook muestra como usar la interfaz API de Spark Data Sources para leer formatos de ficheros:
#  * Parquet
#  * JSON
#  * CSV
#  * Avro
#  * ORC
#  * Image
#  * Binary

# %% [markdown]
# #### Definimos los distintos ficheros

# %%
parquet_file = "/databricks-datasets/learning-spark-v2/flights/summary-data/parquet/2010-summary.parquet"
json_file = "/databricks-datasets/learning-spark-v2/flights/summary-data/json/*"
csv_file = "/databricks-datasets/learning-spark-v2/flights/summary-data/csv/*"
orc_file = "/databricks-datasets/learning-spark-v2/flights/summary-data/orc/*"
avro_file = "/databricks-datasets/learning-spark-v2/flights/summary-data/avro/*"
schema = "DEST_COUNTRY_NAME STRING, ORIGIN_COUNTRY_NAME STRING, count INT"

# %% [markdown]
# ## Parquet Data Source

# %%
parquet_df = spark.read.format("parquet").option("path", parquet_file).load()

# %% [markdown]
# #### Otra forma de leer el fichero usando una variación de esta API

# %%
parquet_df2 = spark.read.parquet(parquet_file)

# %%
parquet_df.show(10, False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |1    |
# |United States    |Ireland            |264  |
# |United States    |India              |69   |
# |Egypt            |United States      |24   |
# |Equatorial Guinea|United States      |1    |
# |United States    |Singapore          |25   |
# |United States    |Grenada            |54   |
# |Costa Rica       |United States      |477  |
# |Senegal          |United States      |29   |
# |United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## SQL
#
# #### Crear una vista temporal sin gestión

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW us_delay_flights_tbl USING parquet OPTIONS (path "/databricks-datasets/definitive-guide/data/flight-data/parquet/2010-summary.parquet")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Utilizamos SQL para visualizar la tabla

# %%
spark.sql("SELECT * FROM us_delay_flights_tbl").show(10, truncate=False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |1    |
# |United States    |Ireland            |264  |
# |United States    |India              |69   |
# |Egypt            |United States      |24   |
# |Equatorial Guinea|United States      |1    |
# |United States    |Singapore          |25   |
# |United States    |Grenada            |54   |
# |Costa Rica       |United States      |477  |
# |Senegal          |United States      |29   |
# |United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## JSON Data Source

# %%
json_df = spark.read.format("json").option("path", json_file).load()

# %%
json_df.show(10, truncate=False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |15   |
# |United States    |Croatia            |1    |
# |United States    |Ireland            |344  |
# |Egypt            |United States      |15   |
# |United States    |India              |62   |
# |United States    |Singapore          |1    |
# |United States    |Grenada            |62   |
# |Costa Rica       |United States      |588  |
# |Senegal          |United States      |40   |
# |Moldova          |United States      |1    |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# #### Otra forma de leer el fichero usando una variación de esta API

# %%
json_df2 = spark.read.json(json_file)

# %%
json_df2.show(10, False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |15   |
# |United States    |Croatia            |1    |
# |United States    |Ireland            |344  |
# |Egypt            |United States      |15   |
# |United States    |India              |62   |
# |United States    |Singapore          |1    |
# |United States    |Grenada            |62   |
# |Costa Rica       |United States      |588  |
# |Senegal          |United States      |40   |
# |Moldova          |United States      |1    |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## SQL
#
# #### Crear una vista temporal sin gestión

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW us_delay_flights_tbl USING json OPTIONS (path "/databricks-datasets/learning-spark-v2/flights/summary-data/json/*")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Utilizamos SQL para visualizar la tabla

# %%
spark.sql("SELECT * FROM us_delay_flights_tbl").show(10, truncate=False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |15   |
# |United States    |Croatia            |1    |
# |United States    |Ireland            |344  |
# |Egypt            |United States      |15   |
# |United States    |India              |62   |
# |United States    |Singapore          |1    |
# |United States    |Grenada            |62   |
# |Costa Rica       |United States      |588  |
# |Senegal          |United States      |40   |
# |Moldova          |United States      |1    |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## CSV Data Source

# %%
csv_df = (spark.read.format("csv").option("header", "true").schema(schema)
         .option("mode", "FAILFAST") #finaliza la ejecución si hay algún error
         .option("nullValue", "") #si hay algún valor nulo lo reemplaza por ""
         .option("path", csv_file).load())

# %%
csv_df.show(10, truncate=False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |1    |
# |United States    |Ireland            |264  |
# |United States    |India              |69   |
# |Egypt            |United States      |24   |
# |Equatorial Guinea|United States      |1    |
# |United States    |Singapore          |25   |
# |United States    |Grenada            |54   |
# |Costa Rica       |United States      |477  |
# |Senegal          |United States      |29   |
# |United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %%
csv_df.write.format("parquet").mode("overwrite").option("path", "/tmp/data/parquet/df_parquet").option("compression", "snappy").save()

# %%
# %fs ls /tmp/data/parquet/df_parquet
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/tmp/data/parquet/df_parquet/_committed_1586011079372287289</td><td>_committed_1586011079372287289</td><td>1223</td><td>1651236065000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/_committed_4648300368014824127</td><td>_committed_4648300368014824127</td><td>624</td><td>1651228130000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/_committed_5275549232530391348</td><td>_committed_5275549232530391348</td><td>1234</td><td>1651228164000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/_committed_696789220469223954</td><td>_committed_696789220469223954</td><td>1217</td><td>1651236104000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/_committed_vacuum8453186849780295908</td><td>_committed_vacuum8453186849780295908</td><td>96</td><td>1651236067000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/_started_1586011079372287289</td><td>_started_1586011079372287289</td><td>0</td><td>1651236064000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/_started_696789220469223954</td><td>_started_696789220469223954</td><td>0</td><td>1651236103000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00000-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-833-1-c000.snappy.parquet</td><td>part-00000-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-833-1-c000.snappy.parquet</td><td>5449</td><td>1651236103000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00001-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-834-1-c000.snappy.parquet</td><td>part-00001-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-834-1-c000.snappy.parquet</td><td>5409</td><td>1651236103000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00002-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-835-1-c000.snappy.parquet</td><td>part-00002-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-835-1-c000.snappy.parquet</td><td>5363</td><td>1651236103000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00003-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-836-1-c000.snappy.parquet</td><td>part-00003-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-836-1-c000.snappy.parquet</td><td>5412</td><td>1651236103000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00004-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-837-1-c000.snappy.parquet</td><td>part-00004-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-837-1-c000.snappy.parquet</td><td>5319</td><td>1651236103000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00005-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-838-1-c000.snappy.parquet</td><td>part-00005-tid-696789220469223954-c980be47-e6ec-4748-b962-414d077a70a3-838-1-c000.snappy.parquet</td><td>5212</td><td>1651236103000</td></tr></tbody></table></div>

# %%
csv_df2 = (spark.read.option("header", "true")
  .option("mode", "FAILFAST") # finaliza la ejecución si hay algún error
  .option("nullValue", "") # si hay algún valor nulo lo reemplaza por ""
  .schema(schema).csv(csv_file))

# %%
csv_df2.show(10, truncate=False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |1    |
# |United States    |Ireland            |264  |
# |United States    |India              |69   |
# |Egypt            |United States      |24   |
# |Equatorial Guinea|United States      |1    |
# |United States    |Singapore          |25   |
# |United States    |Grenada            |54   |
# |Costa Rica       |United States      |477  |
# |Senegal          |United States      |29   |
# |United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## SQL
#
# #### Crear una vista temporal sin gestión

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW us_delay_flights_tbl USING csv OPTIONS (
      path "/databricks-datasets/learning-spark-v2/flights/summary-data/csv/*",
      header "true",
      inferSchema "true",
      mode "FAILFAST"
    )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Utilizamos SQL para visualizar la tabla

# %%
spark.sql("SELECT * FROM us_delay_flights_tbl").show(10, truncate=False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |1    |
# |United States    |Ireland            |264  |
# |United States    |India              |69   |
# |Egypt            |United States      |24   |
# |Equatorial Guinea|United States      |1    |
# |United States    |Singapore          |25   |
# |United States    |Grenada            |54   |
# |Costa Rica       |United States      |477  |
# |Senegal          |United States      |29   |
# |United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## ORC Data Source

# %%
orc_df = spark.read.format("orc").option("path", orc_file).load()

# %%
orc_df.show(10, truncate=False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |1    |
# |United States    |Ireland            |264  |
# |United States    |India              |69   |
# |Egypt            |United States      |24   |
# |Equatorial Guinea|United States      |1    |
# |United States    |Singapore          |25   |
# |United States    |Grenada            |54   |
# |Costa Rica       |United States      |477  |
# |Senegal          |United States      |29   |
# |United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## SQL
#
# #### Crear una vista temporal sin gestión

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW us_delay_flights_tbl USING orc OPTIONS (path "/databricks-datasets/learning-spark-v2/flights/summary-data/orc/*")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Utilizamos SQL para visualizar la tabla

# %%
spark.sql("SELECT * FROM us_delay_flights_tbl").show(10, truncate=False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |1    |
# |United States    |Ireland            |264  |
# |United States    |India              |69   |
# |Egypt            |United States      |24   |
# |Equatorial Guinea|United States      |1    |
# |United States    |Singapore          |25   |
# |United States    |Grenada            |54   |
# |Costa Rica       |United States      |477  |
# |Senegal          |United States      |29   |
# |United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## Avro Data Source

# %%
avro_df = spark.read.format("avro").option("path", avro_file).load()

# %%
avro_df.show(10, truncate=False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |1    |
# |United States    |Ireland            |264  |
# |United States    |India              |69   |
# |Egypt            |United States      |24   |
# |Equatorial Guinea|United States      |1    |
# |United States    |Singapore          |25   |
# |United States    |Grenada            |54   |
# |Costa Rica       |United States      |477  |
# |Senegal          |United States      |29   |
# |United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## SQL
#
# #### Crear una vista temporal sin gestión

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW us_delay_flights_tbl USING avro OPTIONS (path "/databricks-datasets/learning-spark-v2/flights/summary-data/avro/*")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Utilizamos SQL para visualizar la tabla

# %%
spark.sql("SELECT * FROM us_delay_flights_tbl").show(10, truncate=False)
# Out:
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |United States    |Romania            |1    |
# |United States    |Ireland            |264  |
# |United States    |India              |69   |
# |Egypt            |United States      |24   |
# |Equatorial Guinea|United States      |1    |
# |United States    |Singapore          |25   |
# |United States    |Grenada            |54   |
# |Costa Rica       |United States      |477  |
# |Senegal          |United States      |29   |
# |United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ## Image

# %%
from pyspark.ml import image

image_dir = "/databricks-datasets/cctvVideos/train_images/"
images_df = spark.read.format("image").load(image_dir)
images_df.printSchema()

images_df.select("image.height", "image.width", "image.nChannels", "image.mode", "label").show(5, truncate=False)
# Out:
# root
#  |-- image: struct (nullable = true)
#  |    |-- origin: string (nullable = true)
#  |    |-- height: integer (nullable = true)
#  |    |-- width: integer (nullable = true)
#  |    |-- nChannels: integer (nullable = true)
#  |    |-- mode: integer (nullable = true)
#  |    |-- data: binary (nullable = true)
#  |-- label: integer (nullable = true)
#
# +------+-----+---------+----+-----+
# |height|width|nChannels|mode|label|
# +------+-----+---------+----+-----+
# |288   |384  |3        |16  |0    |
# |288   |384  |3        |16  |1    |
# |288   |384  |3        |16  |0    |
# |288   |384  |3        |16  |0    |
# |288   |384  |3        |16  |0    |
# +------+-----+---------+----+-----+
# only showing top 5 rows

# %% [markdown]
# ## Binary

# %%
path = "/databricks-datasets/learning-spark-v2/cctvVideos/train_images/"
binary_files_df = spark.read.format("binaryFile").option("pathGlobFilter", "*.jpg").load(path)

binary_files_df.show(5)
# Out:
# +--------------------+-------------------+------+--------------------+-----+
# |                path|   modificationTime|length|             content|label|
# +--------------------+-------------------+------+--------------------+-----+
# |dbfs:/databricks-...|2020-01-02 20:42:21| 55037|[FF D8 FF E0 00 1...|    0|
# |dbfs:/databricks-...|2020-01-02 20:42:31| 54634|[FF D8 FF E0 00 1...|    1|
# |dbfs:/databricks-...|2020-01-02 20:42:21| 54624|[FF D8 FF E0 00 1...|    0|
# |dbfs:/databricks-...|2020-01-02 20:42:22| 54505|[FF D8 FF E0 00 1...|    0|
# |dbfs:/databricks-...|2020-01-02 20:42:22| 54475|[FF D8 FF E0 00 1...|    0|
# +--------------------+-------------------+------+--------------------+-----+
# only showing top 5 rows

# %% [markdown]
# Para ignorar cualquier particion de datos en un directorio, podemos poner la opción `recursiveFileLookup` a `true`

# %%
binary_files_df = spark.read.format("binaryFile").option("pathGlobFilter", "*.jpg").option("recursiveFileLookup", "true").load(path)

binary_files_df.show(5)
# Out:
# +--------------------+-------------------+------+--------------------+
# |                path|   modificationTime|length|             content|
# +--------------------+-------------------+------+--------------------+
# |dbfs:/databricks-...|2020-01-02 20:42:21| 55037|[FF D8 FF E0 00 1...|
# |dbfs:/databricks-...|2020-01-02 20:42:31| 54634|[FF D8 FF E0 00 1...|
# |dbfs:/databricks-...|2020-01-02 20:42:21| 54624|[FF D8 FF E0 00 1...|
# |dbfs:/databricks-...|2020-01-02 20:42:22| 54505|[FF D8 FF E0 00 1...|
# |dbfs:/databricks-...|2020-01-02 20:42:22| 54475|[FF D8 FF E0 00 1...|
# +--------------------+-------------------+------+--------------------+
# only showing top 5 rows
