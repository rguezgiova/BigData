# %% [markdown]
# ## Spark Data Sources
#
# Este notebook muestra como usar la interfaz API de Spark Data Sources para leer formatos de ficheros:
# * Parquet
#  * JSON
#  * CSV
#  * Avro
#  * ORC
#  * Image
#  * Binary

# %% [markdown]
# #### Definimos los distintos ficheros

# %%
# %scala
val parquetFile = "/databricks-datasets/learning-spark-v2/flights/summary-data/parquet/2010-summary.parquet"
val jsonFile = "/databricks-datasets/learning-spark-v2/flights/summary-data/json/*"
val csvFile = "/databricks-datasets/learning-spark-v2/flights/summary-data/csv/*"
val orcFile = "/databricks-datasets/learning-spark-v2/flights/summary-data/orc/*"
val avroFile = "/databricks-datasets/learning-spark-v2/flights/summary-data/avro/*"
val schema = "DEST_COUNTRY_NAME STRING, ORIGIN_COUNTRY_NAME STRING, count INT"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">parquetFile: String = /databricks-datasets/learning-spark-v2/flights/summary-data/parquet/2010-summary.parquet
# jsonFile: String = /databricks-datasets/learning-spark-v2/flights/summary-data/json/*
# csvFile: String = /databricks-datasets/learning-spark-v2/flights/summary-data/csv/*
# orcFile: String = /databricks-datasets/learning-spark-v2/flights/summary-data/orc/*
# avroFile: String = /databricks-datasets/learning-spark-v2/flights/summary-data/avro/*
# schema: String = DEST_COUNTRY_NAME STRING, ORIGIN_COUNTRY_NAME STRING, count INT
# </div>

# %% [markdown]
# #### Parquet Data Source

# %%
# %scala
val parquetDf = spark.read.format("parquet").option("path", parquetFile).load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">parquetDf: org.apache.spark.sql.DataFrame = [DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string ... 1 more field]
# </div>

# %% [markdown]
# #### Otra forma de leer el fichero usando una variación de esta API

# %%
# %scala
val parquetDf2 = spark.read.parquet(parquetFile)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">parquetDf2: org.apache.spark.sql.DataFrame = [DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string ... 1 more field]
# </div>

# %%
# %scala
parquetDf.show(10, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |1    |
# United States    |Ireland            |264  |
# United States    |India              |69   |
# Egypt            |United States      |24   |
# Equatorial Guinea|United States      |1    |
# United States    |Singapore          |25   |
# United States    |Grenada            |54   |
# Costa Rica       |United States      |477  |
# Senegal          |United States      |29   |
# United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ## SQL
#
# #### Crear una vista temporal sin gestión

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW us_delay_flights_tbl USING parquet OPTIONS (path "/databricks-datasets/definitive-guide/data/flight-data/parquet/2010-summary.parquet")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Utilizamos SQL para visualizar la tabla

# %%
# %scala
spark.sql("SELECT * FROM us_delay_flights_tbl").show(10, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |1    |
# United States    |Ireland            |264  |
# United States    |India              |69   |
# Egypt            |United States      |24   |
# Equatorial Guinea|United States      |1    |
# United States    |Singapore          |25   |
# United States    |Grenada            |54   |
# Costa Rica       |United States      |477  |
# Senegal          |United States      |29   |
# United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ## JSON Data Source

# %%
# %scala
val jsonDf = spark.read.format("json").option("path", jsonFile).load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">jsonDf: org.apache.spark.sql.DataFrame = [DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string ... 1 more field]
# </div>

# %%
# %scala
jsonDf.show(10, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |15   |
# United States    |Croatia            |1    |
# United States    |Ireland            |344  |
# Egypt            |United States      |15   |
# United States    |India              |62   |
# United States    |Singapore          |1    |
# United States    |Grenada            |62   |
# Costa Rica       |United States      |588  |
# Senegal          |United States      |40   |
# Moldova          |United States      |1    |
# +-----------------+-------------------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ## SQL
#
# #### Crear una vista temporal sin gestión

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW us_delay_flights_tbl USING json OPTIONS (path "/databricks-datasets/learning-spark-v2/flights/summary-data/json/*")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Utilizamos SQL para visualizar la tabla

# %%
# %scala
spark.sql("SELECT * FROM us_delay_flights_tbl").show(10, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |15   |
# United States    |Croatia            |1    |
# United States    |Ireland            |344  |
# Egypt            |United States      |15   |
# United States    |India              |62   |
# United States    |Singapore          |1    |
# United States    |Grenada            |62   |
# Costa Rica       |United States      |588  |
# Senegal          |United States      |40   |
# Moldova          |United States      |1    |
# +-----------------+-------------------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ## CSV Data Source

# %%
# %scala
val csvDf = spark.read.format("csv").option("header", "true").schema(schema)
  .option("mode", "FAILFAST") //finaliza la ejecución si hay algún error
  .option("nullValue", "") //si hay algún valor nulo lo reemplaza por ""
  .option("path", csvFile).load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">csvDf: org.apache.spark.sql.DataFrame = [DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string ... 1 more field]
# </div>

# %%
# %scala
csvDf.show(10, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |1    |
# United States    |Ireland            |264  |
# United States    |India              |69   |
# Egypt            |United States      |24   |
# Equatorial Guinea|United States      |1    |
# United States    |Singapore          |25   |
# United States    |Grenada            |54   |
# Costa Rica       |United States      |477  |
# Senegal          |United States      |29   |
# United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows
#
# </div>

# %%
# %scala
csvDf.write.format("parquet").mode("overwrite").option("path", "/tmp/data/parquet/df_parquet").option("compression", "snappy").save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /tmp/data/parquet/df_parquet
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/tmp/data/parquet/df_parquet/_SUCCESS</td><td>_SUCCESS</td><td>0</td><td>1651228165000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/_committed_4648300368014824127</td><td>_committed_4648300368014824127</td><td>624</td><td>1651228130000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/_committed_5275549232530391348</td><td>_committed_5275549232530391348</td><td>1234</td><td>1651228164000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/_started_4648300368014824127</td><td>_started_4648300368014824127</td><td>0</td><td>1651228128000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/_started_5275549232530391348</td><td>_started_5275549232530391348</td><td>0</td><td>1651228163000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00000-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-335-1-c000.snappy.parquet</td><td>part-00000-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-335-1-c000.snappy.parquet</td><td>5449</td><td>1651228163000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00001-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-336-1-c000.snappy.parquet</td><td>part-00001-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-336-1-c000.snappy.parquet</td><td>5409</td><td>1651228163000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00002-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-337-1-c000.snappy.parquet</td><td>part-00002-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-337-1-c000.snappy.parquet</td><td>5363</td><td>1651228163000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00003-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-338-1-c000.snappy.parquet</td><td>part-00003-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-338-1-c000.snappy.parquet</td><td>5412</td><td>1651228163000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00004-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-339-1-c000.snappy.parquet</td><td>part-00004-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-339-1-c000.snappy.parquet</td><td>5319</td><td>1651228163000</td></tr><tr><td>dbfs:/tmp/data/parquet/df_parquet/part-00005-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-340-1-c000.snappy.parquet</td><td>part-00005-tid-5275549232530391348-ad596182-f78f-4221-9e32-8e89691513bd-340-1-c000.snappy.parquet</td><td>5212</td><td>1651228163000</td></tr></tbody></table></div>

# %%
# %scala
val csvDf2 = spark.read.option("header", "true")
  .option("mode", "FAILFAST") //finaliza la ejecución si hay algún error
  .option("nullValue", "") //si hay algún valor nulo lo reemplaza por ""
  .schema(schema).csv(csvFile)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">csvDf2: org.apache.spark.sql.DataFrame = [DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string ... 1 more field]
# </div>

# %%
# %scala
csvDf2.show(10, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |1    |
# United States    |Ireland            |264  |
# United States    |India              |69   |
# Egypt            |United States      |24   |
# Equatorial Guinea|United States      |1    |
# United States    |Singapore          |25   |
# United States    |Grenada            |54   |
# Costa Rica       |United States      |477  |
# Senegal          |United States      |29   |
# United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ## SQL
#
# #### Crear una vista temporal sin gestión

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW us_delay_flights_tbl USING csv OPTIONS (
    path "/databricks-datasets/learning-spark-v2/flights/summary-data/csv/*",
    header "true",
    inferSchema "true",
    mode "FAILFAST"
  )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Utilizamos SQL para visualizar la tabla

# %%
# %scala
spark.sql("SELECT * FROM us_delay_flights_tbl").show(10, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |1    |
# United States    |Ireland            |264  |
# United States    |India              |69   |
# Egypt            |United States      |24   |
# Equatorial Guinea|United States      |1    |
# United States    |Singapore          |25   |
# United States    |Grenada            |54   |
# Costa Rica       |United States      |477  |
# Senegal          |United States      |29   |
# United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ## ORC Data Source

# %%
# %scala
val orcDf = spark.read.format("orc").option("path", orcFile).load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">orcDf: org.apache.spark.sql.DataFrame = [DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string ... 1 more field]
# </div>

# %%
# %scala
orcDf.show(10, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |1    |
# United States    |Ireland            |264  |
# United States    |India              |69   |
# Egypt            |United States      |24   |
# Equatorial Guinea|United States      |1    |
# United States    |Singapore          |25   |
# United States    |Grenada            |54   |
# Costa Rica       |United States      |477  |
# Senegal          |United States      |29   |
# United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ## SQL
#
# #### Crear una vista temporal sin gestión

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW us_delay_flights_tbl USING orc OPTIONS (path "/databricks-datasets/learning-spark-v2/flights/summary-data/orc/*")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Utilizamos SQL para visualizar la tabla

# %%
# %scala
spark.sql("SELECT * FROM us_delay_flights_tbl").show(10, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |1    |
# United States    |Ireland            |264  |
# United States    |India              |69   |
# Egypt            |United States      |24   |
# Equatorial Guinea|United States      |1    |
# United States    |Singapore          |25   |
# United States    |Grenada            |54   |
# Costa Rica       |United States      |477  |
# Senegal          |United States      |29   |
# United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ## Avro Data Source

# %%
# %scala
val avroDf = spark.read.format("avro").option("path", avroFile).load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">avroDf: org.apache.spark.sql.DataFrame = [DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string ... 1 more field]
# </div>

# %%
# %scala
avroDf.show(10, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |1    |
# United States    |Ireland            |264  |
# United States    |India              |69   |
# Egypt            |United States      |24   |
# Equatorial Guinea|United States      |1    |
# United States    |Singapore          |25   |
# United States    |Grenada            |54   |
# Costa Rica       |United States      |477  |
# Senegal          |United States      |29   |
# United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ## SQL
#
# #### Crear una vista temporal sin gestión

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW us_delay_flights_tbl USING avro OPTIONS (path "/databricks-datasets/learning-spark-v2/flights/summary-data/avro/*")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Utilizamos SQL para visualizar la tabla

# %%
# %scala
spark.sql("SELECT * FROM us_delay_flights_tbl").show(10, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |1    |
# United States    |Ireland            |264  |
# United States    |India              |69   |
# Egypt            |United States      |24   |
# Equatorial Guinea|United States      |1    |
# United States    |Singapore          |25   |
# United States    |Grenada            |54   |
# Costa Rica       |United States      |477  |
# Senegal          |United States      |29   |
# United States    |Marshall Islands   |44   |
# +-----------------+-------------------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ## Image

# %%
# %scala
import org.apache.spark.ml.source.image

val imageDir = "/databricks-datasets/cctvVideos/train_images/"
val imagesDf = spark.read.format("image").load(imageDir)

imagesDf.printSchema
imagesDf.select("image.height", "image.width", "image.nChannels", "image.mode", "label").show(5, false)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- image: struct (nullable = true)
#     |-- origin: string (nullable = true)
#     |-- height: integer (nullable = true)
#     |-- width: integer (nullable = true)
#     |-- nChannels: integer (nullable = true)
#     |-- mode: integer (nullable = true)
#     |-- data: binary (nullable = true)
# -- label: integer (nullable = true)
#
# +------+-----+---------+----+-----+
# height|width|nChannels|mode|label|
# +------+-----+---------+----+-----+
# 288   |384  |3        |16  |0    |
# 288   |384  |3        |16  |1    |
# 288   |384  |3        |16  |0    |
# 288   |384  |3        |16  |0    |
# 288   |384  |3        |16  |0    |
# +------+-----+---------+----+-----+
# only showing top 5 rows
#
# import org.apache.spark.ml.source.image
# imageDir: String = /databricks-datasets/cctvVideos/train_images/
# imagesDf: org.apache.spark.sql.DataFrame = [image: struct&lt;origin: string, height: int ... 4 more fields&gt;, label: int]
# </div>

# %% [markdown]
# ## Binary

# %%
# %scala
val path = "/databricks-datasets/learning-spark-v2/cctvVideos/train_images/"
val binaryFilesDf = spark.read.format("binaryFile").option("pathGlobFilter", "*.jpg").load(path)

binaryFilesDf.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------------------+------+--------------------+-----+
#                 path|   modificationTime|length|             content|label|
# +--------------------+-------------------+------+--------------------+-----+
# dbfs:/databricks-...|2020-01-02 20:42:21| 55037|[FF D8 FF E0 00 1...|    0|
# dbfs:/databricks-...|2020-01-02 20:42:31| 54634|[FF D8 FF E0 00 1...|    1|
# dbfs:/databricks-...|2020-01-02 20:42:21| 54624|[FF D8 FF E0 00 1...|    0|
# dbfs:/databricks-...|2020-01-02 20:42:22| 54505|[FF D8 FF E0 00 1...|    0|
# dbfs:/databricks-...|2020-01-02 20:42:22| 54475|[FF D8 FF E0 00 1...|    0|
# +--------------------+-------------------+------+--------------------+-----+
# only showing top 5 rows
#
# path: String = /databricks-datasets/learning-spark-v2/cctvVideos/train_images/
# binaryFilesDf: org.apache.spark.sql.DataFrame = [path: string, modificationTime: timestamp ... 3 more fields]
# </div>

# %% [markdown]
# Para ignorar cualquier particion de datos en un directorio, podemos poner la opción `recursiveFileLookup` a `true`

# %%
# %scala
val binaryFilesDf = spark.read.format("binaryFile").option("pathGlobFilter", "*.jpg").option("recursiveFileLookup", "true").load(path)

binaryFilesDf.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------------------+------+--------------------+
#                 path|   modificationTime|length|             content|
# +--------------------+-------------------+------+--------------------+
# dbfs:/databricks-...|2020-01-02 20:42:21| 55037|[FF D8 FF E0 00 1...|
# dbfs:/databricks-...|2020-01-02 20:42:31| 54634|[FF D8 FF E0 00 1...|
# dbfs:/databricks-...|2020-01-02 20:42:21| 54624|[FF D8 FF E0 00 1...|
# dbfs:/databricks-...|2020-01-02 20:42:22| 54505|[FF D8 FF E0 00 1...|
# dbfs:/databricks-...|2020-01-02 20:42:22| 54475|[FF D8 FF E0 00 1...|
# +--------------------+-------------------+------+--------------------+
# only showing top 5 rows
#
# binaryFilesDf: org.apache.spark.sql.DataFrame = [path: string, modificationTime: timestamp ... 2 more fields]
# </div>
